# %% [markdown]
# # **Chapter.1 파이썬**
#
# 1.1   파이썬
#
#
#     *   간단하고 배우기 쉬운 프로그래밍 언어
#     *   파이썬 자체의 뛰어난 성능에 넘파이와 사아파이 같은 수치 계산과 통계 처리로 데이터 과학 분야에서 확고함
#
#
# 1.2   파이썬 인터프리티
#
#     1.2.1   산술 연산
#
#     1.2.2.  자료형
#
#         *   정수, 실수, 문자열과 같은 형태
#         *   type() 함수로 확인 가능
#
#     1.2.3   변수
#
#         *   x, y 같은 문자를 이용하여 변수 정의 가능
#         *   변수를 이용하여 계산 혹은 변수에 다른 값 대입 가능
#
#     1,2.4   리스트
#
#         *   여러 데이터를 리스트로 정리 가능
#         *   [ ] <-리스트를 생성
#         *   슬라이싱 기법을 통해 원하는 리스트만 얻음 ex) a[0:2], a[0:-2]
#
#     1.2.5   딕셔너리
#
#         *   키와 값을 한 쌍으로 저장
#         *   { } <- 딕셔너리 생성
#
#     1.2.6   bool
#
#         *   True(참), False(거짓) 두 값중 하나르 취함
#         *   and, or, not 연산자 사용가능
#
#     1.2.7   if문
#
#         *   조건에 따라서 if 혹은 else 문을 사용
#
#     1.2.8   for문
#
#         *   반복에는 for문 사용
#
#     1.2.9   함수
#
#         *   특정 기능을 수행하는 명령어를 하나로 묶어 하나의 함수로 정의
#
#
# 1.3   넘파이
#
#   *   딥러닝 구현 중 배열이난 행렬 계산에서 넘파이 사용
#
#
#     1.3.1  넘파이 가져오기
#
#         *   import numpy as np <- 명령어를 통해 앞으로 넘파이가 제공하는 매서드를 np를 통해 참조
#
#     1.3.2   넘파이 배열 생성
#
#         *   np.array() <- 매서드 이용
#         *   np.array()는 파이썬의 리스트를 인수로 받아 (numpy.ndarray)의 특수한 형태의 배열로 변환
#
#     1.3.3   넘파이 산술 연산
#
#         *   원소별로 산술
#
#     1.3.4   넘파이 n차원 배열
#
#         *   1차원뿐만 아니라 다차원 작성 가능
#
#     1.3.5   브로드캐스트
#
#         *   형상이 다른 배열도 계산 가능
#
#     1.3.6   원소 접근
#         *   원소의 인덱스는 0부터 시작
#         *
